# %%
#Step 1: Simulate Transaction Data
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import random

# Define item pool
items = ['Bread', 'Milk', 'Eggs', 'Cheese', 'Butter', 'Apples', 'Bananas', 'Yogurt']

# Generate 10 transactions
transactions = []
for _ in range(10):
    num_items = random.randint(2, 5)
    transaction = random.sample(items, num_items)
    transactions.append(transaction)
# Step 1: Simulate Transaction Data
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import random

# Item pool
items = ['Bread', 'Milk', 'Eggs', 'Cheese', 'Butter', 'Apples', 'Bananas', 'Yogurt']

# Generate 10 transactions
transactions = []
for _ in range(10):
    num_items = random.randint(2, 5)
    transaction = random.sample(items, num_items)
    transactions.append(transaction)

# Convert to DataFrame for one-hot encoding
df = pd.DataFrame(columns=items)
for transaction in transactions:
    row = {item: (item in transaction) for item in items}
    df = pd.concat([df, pd.DataFrame([row])], ignore_index=True)

print("One-hot encoded transactions:")
print(df)

# Apply Apriori Algorithm
frequent_itemsets = apriori(df, min_support=0.3, use_colnames=True)
print("\nFrequent Itemsets:")
print(frequent_itemsets)

# Generate Association Rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
print("\nAssociation Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])

# Choose and explain a rule (example)
if not rules.empty:
    rule = rules.iloc[0]
    print(f"\nExample Rule: If a customer buys {list(rule['antecedents'])}, "
          f"they are likely to also buy {list(rule['consequents'])} "
          f"with {rule['confidence']*100:.0f}% confidence.")
# Out:
# One-hot encoded transactions:
#    Bread   Milk   Eggs Cheese Butter Apples Bananas Yogurt
# 0   True  False  False   True  False  False    True   True
# 1   True   True  False   True  False   True    True  False
# 2   True  False  False   True  False  False    True  False
# 3  False   True  False  False  False  False   False   True
# 4   True  False  False   True  False  False   False   True
# 5   True   True  False  False  False   True    True   True
# 6   True   True  False   True   True  False   False  False
# 7   True  False  False  False   True   True    True   True
# 8  False   True   True   True  False  False    True  False
# 9   True  False  False  False  False  False   False   True
#
# Frequent Itemsets:
#    support                  itemsets
# 0      0.8                   (Bread)
# 1      0.5                    (Milk)
# 2      0.6                  (Cheese)
# 3      0.3                  (Apples)
# 4      0.6                 (Bananas)
# 5      0.6                  (Yogurt)
# ...
